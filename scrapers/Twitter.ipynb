# %% [markdown]
# # Mining the social web: Twitter

# %% [markdown]
# ### Creating new App
# To create a new App from Twitter API you need a Twitter account, then follow the instructions here:
# https://dev.twitter.com/oauth/overview/application-owner-access-tokens

# %% [markdown]
# ### Initializing API

# %%
import twitter
#import os
#CONSUMER_KEY = os.environ['TWITTER_CONSUMER_KEY']
#CONSUMER_SECRET = os.environ['TWITTER_CONSUMER_SECRET']
#OAUTH_TOKEN = os.environ['TWITTER_ACCESS_TOKEN']
#OAUTH_TOKEN_SECRET = os.environ['TWITTER_ACCESS_SECRET']

config = {}
execfile("config.py", config)

auth = twitter.oauth.OAuth(config['TWITTER_ACCESS_KEY'], config['TWITTER_ACCESS_SECRET'],
                           config['TWITTER_CONSUMER_KEY'], config['TWITTER_CONSUMER_SECRET'])

twitter_api = twitter.Twitter(auth=auth)

# %% [markdown]
# ### Trending topics in the world and Mexico
# Using Yahoo's Where On Earth ID (WOEID)
#
# A list of countries' IDs: http://www.knowbeforeyougo.co/yahooWOEIDs.cfm

# %%
import json
# The Yahoo! Where On Earth ID for the entire world is 1 and for mexico is 116545.
WORLD_WOE_ID = 1
MX_WOE_ID = 116545

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
mx_trends = twitter_api.trends.place(_id=MX_WOE_ID)

# %%
import pandas as pn
# pandas's data frames are easier on the eye.
wtrends_df = pn.read_json(json.dumps(world_trends[0]['trends']))
mxtrends_df = pn.read_json(json.dumps(mx_trends[0]['trends']))

# %%
print '**************************************** World ****************************************'
print wtrends_df.head()
print '**************************************** Mexico ****************************************'
print mxtrends_df.head()
# Out:
# **************************************** World ****************************************
#                 name  promoted_content                query  tweet_volume  \
# 0            #UFC209               NaN            %23UFC209       45160.0
# 1        #HayeBellew               NaN        %23HayeBellew      155372.0
# 2      Grayson Allen               NaN  %22Grayson+Allen%22           NaN
# 3  #LugaresQueHablan               NaN  %23LugaresQueHablan           NaN
# 4            Eleanor               NaN              Eleanor      537660.0
#
#                                                url
# 0            http://twitter.com/search?q=%23UFC209
# 1        http://twitter.com/search?q=%23HayeBellew
# 2  http://twitter.com/search?q=%22Grayson+Allen%22
# 3  http://twitter.com/search?q=%23LugaresQueHablan
# 4              http://twitter.com/search?q=Eleanor
# **************************************** Mexico ****************************************
#                 name  promoted_content                    query  tweet_volume  \
# 0  #JanCuakaResponde               NaN      %23JanCuakaResponde       11597.0
# 1          #CruzAzul               NaN              %23CruzAzul           NaN
# 2      #VamosAmerica               NaN          %23VamosAmerica           NaN
# 3            Eleanor               NaN                  Eleanor      537660.0
# 4   #HoyMeFascinaría               NaN  %23HoyMeFascinar%C3%ADa       14354.0
#
#                                                  url
# 0    http://twitter.com/search?q=%23JanCuakaResponde
# 1            http://twitter.com/search?q=%23CruzAzul
# 2        http://twitter.com/search?q=%23VamosAmerica
# 3                http://twitter.com/search?q=Eleanor
# 4  http://twitter.com/search?q=%23HoyMeFascinar%C...

# %% [markdown]
# ### Specific Hashtag

# %%
q = '#LasNoviasGordasSonLoDeHoy' 

count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

print json.dumps(search_results['statuses'][0], indent=1)
# Out:
# {
#  "contributors": null,
#  "truncated": false,
#  "text": "#LasNoviasGordasSonLoDeHoy\n- La Netflix https://t.co/FJkjhnP1CS",
#  "is_quote_status": false,
#  "in_reply_to_status_id": null,
#  "id": 838224783250579456,
#  "favorite_count": 0,
#  "entities": {
#   "symbols": [],
#   "user_mentions": [],
#   "hashtags": [
#    {
#     "indices": [
#      0,
#      26
#     ],
#     "text": "LasNoviasGordasSonLoDeHoy"
#    }
#   ],
#   "urls": [],
#   "media": [
#    {
#     "expanded_url": "https://twitter.com/itzamna_cantu/status/838224783250579456/photo/1",
#     "display_url": "pic.twitter.com/FJkjhnP1CS",
#     "url": "https://t.co/FJkjhnP1CS",
#     "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/C6H4_TsU0AARbpD.jpg",
#     "id_str": "838224772169256960",
#     "sizes": {
#      "small": {
#       "h": 130,
#       "resize": "fit",
#       "w": 244
#      },
#      "large": {
#       "h": 130,
#       "resize": "fit",
#       "w": 244
#      },
#      "medium": {
#       "h": 130,
#       "resize": "fit",
#       "w": 244
#      },
#      "thumb": {
#       "h": 130,
#       "resize": "crop",
#       "w": 130
#      }
#     },
#     "indices": [
#      40,
#      63
#     ],
#     "type": "photo",
#     "id": 838224772169256960,
#     "media_url": "http://pbs.twimg.com/tweet_video_thumb/C6H4_TsU0AARbpD.jpg"
#    }
#   ]
#  },
#  "retweeted": false,
#  "coordinates": null,
#  "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#  "in_reply_to_screen_name": null,
#  "in_reply_to_user_id": null,
#  "retweet_count": 0,
#  "id_str": "838224783250579456",
#  "favorited": false,
#  "user": {
#   "follow_request_sent": false,
#   "has_extended_profile": false,
#   "profile_use_background_image": false,
#   "default_profile_image": false,
#   "id": 333706897,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme2/bg.gif",
#   "verified": false,
#   "translator_type": "none",
#   "profile_text_color": "333333",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/811067862265700352/Cj0X2KqA_normal.jpg",
#   "profile_sidebar_fill_color": "EFEFEF",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/YZA5UvqbPy",
#       "indices": [
#        0,
#        23
#       ],
#       "expanded_url": "https://www.instagram.com/itzamna_/",
#       "display_url": "instagram.com/itzamna_/"
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "followers_count": 2363,
#   "profile_sidebar_border_color": "FFFFFF",
#   "id_str": "333706897",
#   "profile_background_color": "C6E2EE",
#   "listed_count": 33,
#   "is_translation_enabled": false,
#   "utc_offset": -21600,
#   "statuses_count": 66,
#   "description": "Where have you been all my life?... \n   \n          \n  Snap \ud83d\udc7b: luzitzamna",
#   "friends_count": 1081,
#   "location": "M\u00e9xico",
#   "profile_link_color": "89C9FA",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/811067862265700352/Cj0X2KqA_normal.jpg",
#   "following": false,
#   "geo_enabled": false,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/333706897/1482208620",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme2/bg.gif",
#   "screen_name": "itzamna_cantu",
#   "lang": "es",
#   "profile_background_tile": false,
#   "favourites_count": 69,
#   "name": "Luz Itzamna",
#   "notifications": false,
#   "url": "https://t.co/YZA5UvqbPy",
#   "created_at": "Mon Jul 11 23:30:04 +0000 2011",
#   "contributors_enabled": false,
#   "time_zone": "Central Time (US & Canada)",
#   "protected": false,
#   "default_profile": false,
#   "is_translator": false
#  },
#  "geo": null,
#  "in_reply_to_user_id_str": null,
#  "possibly_sensitive": false,
#  "lang": "en",
#  "created_at": "Sun Mar 05 03:08:56 +0000 2017",
#  "in_reply_to_status_id_str": null,
#  "place": null,
#  "extended_entities": {
#   "media": [
#    {
#     "expanded_url": "https://twitter.com/itzamna_cantu/status/838224783250579456/photo/1",
#     "display_url": "pic.twitter.com/FJkjhnP1CS",
#     "url": "https://t.co/FJkjhnP1CS",
#     "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/C6H4_TsU0AARbpD.jpg",
#     "video_info": {
#      "aspect_ratio": [
#       122,
#       65
#      ],
#      "variants": [
#       {
#        "url": "https://video.twimg.com/tweet_video/C6H4_TsU0AARbpD.mp4",
#        "bitrate": 0,
#        "content_type": "video/mp4"
#       }
#      ]
#     },
#     "id_str": "838224772169256960",
#     "sizes": {
#      "small": {
#       "h": 130,
#       "resize": "fit",
#       "w": 244
#      },
#      "large": {
#       "h": 130,
#       "resize": "fit",
#       "w": 244
#      },
#      "medium": {
#       "h": 130,
#       "resize": "fit",
#       "w": 244
#      },
#      "thumb": {
#       "h": 130,
#       "resize": "crop",
#       "w": 130
#      }
#     },
#     "indices": [
#      40,
#      63
#     ],
#     "type": "animated_gif",
#     "id": 838224772169256960,
#     "media_url": "http://pbs.twimg.com/tweet_video_thumb/C6H4_TsU0AARbpD.jpg"
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  }
# }

# %%
df = pn.DataFrame()
for result in search_results["statuses"]:
    df_temp = pn.DataFrame()
    df_temp.loc[0,'created_at'] = result["created_at"]
    df_temp.loc[0, 'screen_name'] = result["user"]["screen_name"]
    df_temp.loc[0, 'text'] = result["text"]
    df = df.append(df_temp)

# %%
df.reset_index(inplace=True)
del df['index']
df.head(10)
# Out:
#                        created_at     screen_name  \
# 0  Sun Mar 05 03:08:56 +0000 2017   itzamna_cantu
# 1  Sun Mar 05 03:08:55 +0000 2017     axelsound09
# 2  Sun Mar 05 03:07:29 +0000 2017    setiestrella
# 3  Sun Mar 05 03:07:13 +0000 2017  ValeriaMarcial
# 4  Sun Mar 05 03:07:09 +0000 2017  cheeringnights
# 5  Sun Mar 05 03:06:46 +0000 2017  cheeringnights
# 6  Sun Mar 05 03:06:46 +0000 2017         latiram
# 7  Sun Mar 05 03:06:15 +0000 2017      LeovyUrban
# 8  Sun Mar 05 03:06:04 +0000 2017        Ambriz_B
# 9  Sun Mar 05 03:05:44 +0000 2017      oxido_leon
#
#                                                 text
# 0  #LasNoviasGordasSonLoDeHoy\n- La Netflix https...
# 1  #LasNoviasGordasSonLoDeHoy\n\n#gordibuenaneces...
# 2  #LasNoviasGordasSonLoDeHoy si quieren una aquí...
# 3  RT @usuarianueva: #LasNoviasGordasSonLoDeHoy p...
# 4  #LasNoviasGordasSonLoDeHoy porque tenemos waff...
# 5  RT @CarneBlanca: Si #LasNoviasGordasSonLoDeHoy...
# 6  #LasNoviasGordasSonLoDeHoy ...pobres aquellos ...
# 7  #LasNoviasGordasSonLoDeHoy para gordas, las de...
# 8  #LasNoviasGordasSonLoDeHoy😭😭 pues yo no veo ...
# 9            #LasNoviasGordasSonLoDeHoy POR MANIAKAS
